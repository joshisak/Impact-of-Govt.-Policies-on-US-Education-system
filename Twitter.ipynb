# %%
import re 
import tweepy 
from tweepy import OAuthHandler 
from textblob import TextBlob

# %%
# keys and tokens from the Twitter Dev Console   
consumer_key = '9H7jm6KJxgMeJcVyPaQJFUXsI'
consumer_secret = 'wkaLONHFeHrP24NeAE8T9w0KytpZwbxyfAcj7ldCGxnaw99HrK'
access_token = '867062604040155136-OZjpWfXepqI6On08ghfVXHd4tiY6yqx'
access_secret = '3AMZ0z06s8Xizfd9Sg9rSl1hMA1pftkNzeLkBDWEDKzWK'

# %%
class TwitterClient(object): 
    ''' 
    Generic Twitter Class for sentiment analysis. 
    '''
    def __init__(self): 
        ''' 
        Class constructor or initialization method. 
        '''
  
        # attempt authentication 
        try: 
            # create OAuthHandler object 
            self.auth = OAuthHandler(consumer_key, consumer_secret) 
            # set access token and secret 
            self.auth.set_access_token(access_token, access_secret) 
            # create tweepy API object to fetch tweets 
            self.api = tweepy.API(self.auth) 
        except: 
            print("Error: Authentication Failed") 
  
    def clean_tweet(self, tweet): 
        ''' 
        Utility function to clean tweet text by removing links, special characters 
        using simple regex statements. 
        '''
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) |(\w+:\/\/\S+)", " ", tweet).split()) 
  
    def get_tweet_sentiment(self, tweet): 
        ''' 
        Utility function to classify sentiment of passed tweet 
        using textblob's sentiment method 
        '''
        # create TextBlob object of passed tweet text 
        analysis = TextBlob(self.clean_tweet(tweet)) 
        # set sentiment 
        if analysis.sentiment.polarity > 0: 
            return 'positive'
        elif analysis.sentiment.polarity == 0: 
            return 'neutral'
        else: 
            return 'negative'
  
    def get_tweets(self, query, count = 10): 
        ''' 
        Main function to fetch tweets and parse them. 
        '''
        # empty list to store parsed tweets 
        tweets = [] 
  
        try: 
            # call twitter api to fetch tweets 
            fetched_tweets = self.api.search(q = query, count = count) 
  
            # parsing tweets one by one 
            for tweet in fetched_tweets: 
                # empty dictionary to store required params of a tweet 
                parsed_tweet = {} 
  
                # saving text of tweet 
                parsed_tweet['text'] = tweet.text 
                # saving sentiment of tweet 
                parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text) 
  
                # appending parsed tweet to tweets list 
                if tweet.retweet_count > 0: 
                    # if tweet has retweets, ensure that it is appended only once 
                    if parsed_tweet not in tweets: 
                        tweets.append(parsed_tweet) 
                else: 
                    tweets.append(parsed_tweet) 
  
            # return parsed tweets 
            return tweets 
  
        except tweepy.TweepError as e: 
            # print error (if any) 
            print("Error : " + str(e)) 
            
def main(): 
    # creating object of TwitterClient Class 
    api = TwitterClient()
    # calling function to get tweets 
    tweets = api.get_tweets(query = 'Covid', count = 200) 
  
    # picking positive tweets from tweets 
    ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive'] 
    # percentage of positive tweets 
    print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets))) 
    # picking negative tweets from tweets 
    ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative'] 
    # percentage of negative tweets 
    print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets))) 
    # percentage of neutral tweets 
    print("Neutral tweets percentage: {} % ".format(100*(len(tweets) -(len( ntweets )+len( ptweets)))/len(tweets))) 
  
    # printing first 5 positive tweets 
    print("\n\nPositive tweets:") 
    for tweet in ptweets[:10]: 
        print(tweet['text']) 
  
    # printing first 5 negative tweets 
    print("\n\nNegative tweets:") 
    for tweet in ntweets[:10]: 
        print(tweet['text']) 

if __name__ == "__main__": 
    # calling main function 
    main()
# Out:
# Positive tweets percentage: 26.041666666666668 %
# Negative tweets percentage: 12.5 %
# Neutral tweets percentage: 61.458333333333336 %
#
#
# Positive tweets:
# RT @CNNnewsroom: More than 160,000 people have died from Covid-19 in the US. @brikeilarCNN highlights some of their stories. https://t.co/C…
# RT @TheNicOfTime_: I’ve fully cancelled some plans I had because there is no way they can be factored into Covid era, in light of the poor…
# Hey you old bitch, @SenSchumer  care to sacrifice yourself first on the alter of covid? Back up your love of the economy? Fuck you
# RT @pipocasclub: 4ª temporada de ‘The Good Doctor’ abordará sobre a Covid-19 https://t.co/zvTEprqPRQ https://t.co/1WNYjFj0vD
# RT @RJSzczerba: Remember, TikTok is a “national emergency,” but COVID-19 will “just go away on its own.”
# RT @T_Lyte: Just experienced my first personal COVID death. She was six.
# 😢
# despite covid it’s nice to see the crowd at the trop looking like normal
# ...

# %%
import twitter

# initialize api instance
twitter_api = twitter.Api(consumer_key=consumer_key,
                        consumer_secret=consumer_secret,
                        access_token_key=access_token,
                        access_token_secret=access_secret)

# test authentication
#print(twitter_api.VerifyCredentials())

# ------------------------------------------------------------------------

def buildTestSet(search_keyword):
    try:
        tweets_fetched = twitter_api.GetSearch(search_keyword, count=200)
        
        print("Fetched " + str(len(tweets_fetched)) + " tweets for the term " + search_keyword)

        return [{"text":status.text, "label":None} for status in tweets_fetched]
    except:
        print("Unfortunately, something went wrong..")
        return None
    
# ------------------------------------------------------------------------

search_term = input("Enter a search keyword: ")
testDataSet = buildTestSet(search_term)

#print(testDataSet[0:4])

# ------------------------------------------------------------------------

# def buildTrainingSet(corpusFile, tweetDataFile):
#     import pandas as pd
#     import csv
#     import time 

#     corpus=[]
    
#     corpus = pd.read_csv("corpus.txt",delimiter=',',header=None)
#     corpus.columns = ['topic','label','tweet_id']
#     corpus["text"] = ' '
#     print(corpus)
#     rate_limit=180
#     sleep_time=900/180
    
#     trainingDataSet=[]
#     print(len(corpus))
#     i=0
#     for ids in corpus["tweet_id"]:
#         #print(ids)
#         try:
#             status = twitter_api.GetStatus(ids)
#             print(i,"Tweet fetched" + status.text)
#             tweet = status.text
#             corpus["text"][i] = tweet
            
            
#             trainingDataSet.append(tweet)
#             #print(i,corpus["text"][i])
#             time.sleep(1)
#             i+=1
#         except Exception as e:
#             print(i,e)
#             i+=1
#             continue
        
#     print(len(trainingDataSet))
#     # Now we write them to the empty CSV file
#     #with open(tweetDataFile,'wb') as csvfile:
# #     linewriter=[]
# #     for tweet in trainingDataSet:
# #         try:
# #             #print(tweet)
# #             linewriter.append([tweet["tweet_id"],tweet["text"],tweet["label"],tweet["topic"]])
# #         except Exception as e:
# #             print(e)
# #     linew = pd.DataFrame(linewriter,columns=["tweet_id","text","label","topic"])
#     corpus.to_csv("tweetDataFile.csv",index=False)
#     return trainingDataSet

# ------------------------------------------------------------------------

#corpusFile = "C:/Users/saksh/Desktop/MSU/1. Anjana/corpus.txt"
#tweetDataFile = "C:/Users/saksh/Desktop/MSU/1. Anjana/tweetDataFile.csv"
import pandas as pd
data = pd.read_csv("C:/Users/saksh/Desktop/MSU/1. Anjana/tweetDataFile.csv")
trainingData = data.to_dict('records')
print(trainingData[:5])

# ------------------------------------------------------------------------

import re
from nltk.tokenize import word_tokenize
from string import punctuation 
from nltk.corpus import stopwords 

class PreProcessTweets:
    def __init__(self):
        self._stopwords = set(stopwords.words('english') + list(punctuation) + ['AT_USER','URL'])
        
    def processTweets(self, list_of_tweets):
        processedTweets=[]
        for tweet in list_of_tweets:
            processedTweets.append((self._processTweet(tweet["text"]),tweet["label"]))
        return processedTweets
    
    def _processTweet(self, tweet):
        tweet = tweet.lower() # convert text to lower-case
        tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', 'URL', tweet) # remove URLs
        tweet = re.sub('@[^\s]+', 'AT_USER', tweet) # remove usernames
        tweet = re.sub(r'#([^\s]+)', r'\1', tweet) # remove the # in #hashtag
        tweet = word_tokenize(tweet) # remove repeated characters (helloooooooo into hello)
        return [word for word in tweet if word not in self._stopwords]
    
tweetProcessor = PreProcessTweets()
preprocessedTrainingSet = tweetProcessor.processTweets(list(trainingData))
preprocessedTestSet = tweetProcessor.processTweets(testDataSet)

# ------------------------------------------------------------------------

import nltk 

def buildVocabulary(preprocessedTrainingData):
    all_words = []
    
    for (words, sentiment) in preprocessedTrainingData:
        all_words.extend(words)

    wordlist = nltk.FreqDist(all_words)
    word_features = wordlist.keys()
    
    return word_features

# ------------------------------------------------------------------------

def extract_features(tweet):
    tweet_words=set(tweet)
    features={}
    for word in word_features:
        features['contains(%s)' % word]=(word in tweet_words)
    return features 

# ------------------------------------------------------------------------

# Now we can extract the features and train the classifier 
word_features = buildVocabulary(preprocessedTrainingSet)
trainingFeatures=nltk.classify.apply_features(extract_features,preprocessedTrainingSet)

# ------------------------------------------------------------------------

NBayesClassifier=nltk.NaiveBayesClassifier.train(trainingFeatures)

# ------------------------------------------------------------------------

NBResultLabels = [NBayesClassifier.classify(extract_features(tweet[0])) for tweet in preprocessedTestSet]

# ------------------------------------------------------------------------

# get the majority vote
if NBResultLabels.count('positive') > NBResultLabels.count('negative'):
    print("Overall Positive Sentiment")
    print("Positive Sentiment Percentage = " + str(100*NBResultLabels.count('positive')/len(NBResultLabels)) + "%")
else: 
    print("Overall Negative Sentiment")
    print("Negative Sentiment Percentage = " + str(100*NBResultLabels.count('negative')/len(NBResultLabels)) + "%")
# Out:
# Enter a search keyword: Covid
# Fetched 100 tweets for the term Covid
# [{'topic': 'apple', 'label': 'positive', 'tweet_id': 1.26416e+17, 'text': 'Now all @Apple has to do is get swype on the iphone and it will be crack. Iphone that is'}, {'topic': 'apple', 'label': 'positive', 'tweet_id': 1.26405e+17, 'text': ' '}, {'topic': 'apple', 'label': 'positive', 'tweet_id': 1.26403e+17, 'text': "Hilarious @youtube video - guy does a duet with @apple 's Siri. Pretty much sums up the love affair! http://t.co/8ExbnQjY"}, {'topic': 'apple', 'label': 'positive', 'tweet_id': 1.26397e+17, 'text': '@RIM you made it too easy for me to switch to @Apple iPhone. See ya!'}, {'topic': 'apple', 'label': 'positive', 'tweet_id': 1.26396e+17, 'text': ' '}]
# Overall Negative Sentiment
# Negative Sentiment Percentage = 16.0%

# %%
import pandas as pd
import numpy as np
import re
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
# ML Libraries
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# Global Parameters
stop_words = set(stopwords.words('english'))

def load_dataset(filename, cols):
    dataset = pd.read_csv(filename, encoding='latin-1')
    dataset= dataset[cols]
    return dataset

def remove_unwanted_cols(dataset, cols):
    for col in cols:
        del dataset[col]
    return dataset

def preprocess_tweet_text(tweet):
    tweet.lower()
    # Remove urls
    tweet = re.sub(r"http\S+|www\S+|https\S+", '', tweet, flags=re.MULTILINE)
    # Remove user @ references and '#' from tweet
    tweet = re.sub(r'\@\w+|\#','', tweet)
    # Remove punctuations
    tweet = tweet.translate(str.maketrans('', '', string.punctuation))
    # Remove stopwords
    tweet_tokens = word_tokenize(tweet)
    filtered_words = [w for w in tweet_tokens if not w in stop_words]
    
    #ps = PorterStemmer()
    #stemmed_words = [ps.stem(w) for w in filtered_words]
    #lemmatizer = WordNetLemmatizer()
    #lemma_words = [lemmatizer.lemmatize(w, pos='a') for w in stemmed_words]
    
    return " ".join(filtered_words)

def get_feature_vector(train_fit):
    vector = TfidfVectorizer(sublinear_tf=True)
    vector.fit(train_fit)
    return vector

def int_to_string(sentiment):
    if sentiment == 0:
        return "Negative"
    elif sentiment == 2:
        return "Neutral"
    else:
        return "Positive"
    
# Load dataset
dataset = load_dataset("17_742210_compressed_Tweets.csv/Tweets.csv", [ 'airline_sentiment', 'tweet_id','airline_sentiment_confidence','negativereason',
                                                                      'negativereason_confidence','text'])
# Remove unwanted columns from dataset
#n_dataset = remove_unwanted_cols(dataset, ['t_id', 'created_at', 'query', 'user'])
#Preprocess data
dataset.text = dataset['text'].apply(preprocess_tweet_text)
# Split dataset into Train, Test

# Same tf vector will be used for Testing sentiments on unseen trending data
tf_vector = get_feature_vector(np.array(dataset.iloc[:, -1]).ravel())
X = tf_vector.transform(np.array(dataset.iloc[:, -1]).ravel())
y = np.array(dataset.iloc[:, 0]).ravel()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)

# Training Naive Bayes model
NB_model = MultinomialNB()
NB_model.fit(X_train, y_train)
y_predict_nb = NB_model.predict(X_test)
print(accuracy_score(y_test, y_predict_nb))

# Training Logistics Regression model
LR_model = LogisticRegression(solver='lbfgs')
LR_model.fit(X_train, y_train)
y_predict_lr = LR_model.predict(X_test)
print(accuracy_score(y_test, y_predict_lr))

#Training Random Forrest Classifier model
from sklearn.ensemble import RandomForestClassifier

RF_model = RandomForestClassifier(n_estimators=200, random_state=0)
RF_model.fit(X_train, y_train)
y_predict_rf = RF_model.predict(X_test)
print(accuracy_score(y_test, y_predict_rf))
# Out:
# 0.6834016393442623
# C:\Users\saksh\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# 0.7838114754098361
# 0.7646857923497268

# %%
# def buildTestSet(search_keyword):
#     try:
#         tweets_fetched = twitter_api.GetSearch(search_keyword, count=200)
        
#         print("Fetched " + str(len(tweets_fetched)) + " tweets for the term " + search_keyword)
        
#         tweets = []
#         for status in tweets_fetched:
#             tweets.append(status.text)
            
#         return pd.DataFrame(tweets,columns=['Text'])
#     except:
#         print("Unfortunately, something went wrong..")
#        return None

def preprocess_tweet_text(tweet):
    tweet.lower()
    # Remove urls
    tweet = re.sub(r"http\S+|www\S+|https\S+", '', tweet, flags=re.MULTILINE)
    # Remove user @ references and '#' from tweet
    tweet = re.sub(r'\@\w+|\#','', tweet)
    # Remove punctuations
    tweet = tweet.translate(str.maketrans('', '', string.punctuation))
    # Remove stopwords
    tweet_tokens = word_tokenize(tweet)
    filtered_words = [w for w in tweet_tokens if not w in stop_words]
    
    #ps = PorterStemmer()
    #stemmed_words = [ps.stem(w) for w in filtered_words]
    #lemmatizer = WordNetLemmatizer()
    #lemma_words = [lemmatizer.lemmatize(w, pos='a') for w in stemmed_words]
    
    return " ".join(filtered_words)

def get_feature_vector(train_fit):
    vector = TfidfVectorizer(sublinear_tf=True)
    vector.fit(train_fit)
    return vector

# ------------------------------------------------------------------------

#search_term = input("Enter a search keyword: ")
testDataSet = pd.read_csv("New folder/2 year business school tweets.csv")#buildTestSet(search_term)
testDataSet = testDataSet[['Tweet']]
testDataSet.Text = testDataSet.Tweet.apply(preprocess_tweet_text)

#tf_vector = get_feature_vector(np.array(testDataSet.iloc[:, 0]).ravel())
Xtest = tf_vector.transform(np.array(testDataSet.iloc[:, 0]).ravel())

y_predict = LR_model.predict(Xtest)
y_predict = pd.DataFrame(y_predict,columns=['Label'])
testDataSet['Label'] = y_predict
print(testDataSet['Label'].value_counts())
#testDataSet.to_csv("twiiter/"+search_term+" tweets.csv",index=False)
# Out:
# C:\Users\saksh\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
# negative    4766
# neutral      691
# positive     382
# Name: Label, dtype: int64

# %%
print(testDataSet['Label'].value_counts())
# 2 yr 81.62%
# covid 90.13
# 6 month 83.77
# Out:
# negative    895
# neutral      82
# positive     16
# Name: Label, dtype: int64

# %%
print(testDataSet['Label'].value_counts())
# Out:
# negative    1357
# neutral      186
# positive      77
# Name: Label, dtype: int64

# %%
def buildTestSet(search_keyword):
    try:
        tweets_fetched = twitter_api.GetSearch(search_keyword, count=500)
        
        print("Fetched " + str(len(tweets_fetched)) + " tweets for the term " + search_keyword)
        
        return [{"text":status.text,"t_id":status.id_str,"created_at":status.created_at} for status in tweets_fetched]# if status.lang=='en']
    except Exception as e:
        print("Unfortunately, something went wrong..", e)
        return None

search_term = input("Enter a search keyword: ")
testDataSet = pd.DataFrame.from_dict(buildTestSet(search_term))
testDataSet.to_csv("latest tweets.csv",index=False)
test_file_name = "latest tweets.csv"
test_ds = load_dataset(test_file_name, ["t_id", "created_at", "text"])
test_ds = remove_unwanted_cols(test_ds, ["t_id", "created_at"])

# Creating text feature
test_ds.text = test_ds["text"].apply(preprocess_tweet_text)
test_feature = tf_vector.transform(np.array(test_ds.iloc[:, 0]).ravel())

# Using Logistic Regression model for prediction
test_prediction_lr = LR_model.predict(test_feature)

# Averaging out the hashtags result
test_ds['Prediction'] = pd.DataFrame(test_prediction_lr,columns=['Prediction'])
#test_result = test_result_ds.groupby(['hashtag']).max().reset_index()
#test_result.columns = ['tweet', 'predictions']
test_ds.Prediction = test_ds['Prediction'].apply(int_to_string)

print(test_ds)
# Out:
# Enter a search keyword: mba
# Fetched 100 tweets for the term mba
#                                                  text Prediction
# 0   I need help Retweet find recruiter No job sinc...   Positive
# 1   Â¡Buen dÃ­a ðð½ââï¸ Al toser estornu...   Positive
# 2   I need help We need job vet No job since Apr 1â¦   Positive
# 3                       mirip itu mba mba sama masnya   Positive
# 4   Siapa yang kalo ke restoran steak niatnya mau ...   Positive
# ..                                                ...        ...
# 95                                 Itu soflens ya mba   Positive
# 96  Saya sendiri akhirakhir ini sedang suka sekali...   Positive
# 97                Y el cien mil Mbae pio pÃ©a prosÃ³r   Positive
# 98                                     gak reti e mba   Positive
# 99      Semoga lekas sembuh untuk Ibu Mba Wiiðð¼   Positive
#
# [100 rows x 2 columns]

# %%
test_ds.to_csv("latest tweets.csv",index=False)

# %%
test_ds.Prediction.value_counts()
# Out:
# Positive    100
# Name: Prediction, dtype: int64

# %%
import time
search_keyword = "mba"
rate_limit=180
sleep_time=900/180
max_id = None
tweets = []
i=0
while i == 0:
    #print("hi")
    tweets_fetched = twitter_api.GetSearch(search_keyword, count=100,max_id=max_id)
    #print(len(tweets_fetched))
    for status in tweets_fetched:
        #print(status.lang)
        if status.lang == 'en':
            ##print(status.text)
            tweets.append({"text":status.text,"t_id":status.id_str,"created_at":status.created_at})
        max_id = status.id_str
    #max_id=min(int(tweets['t_id']))
    print(len(tweets))
    #break
    #time.sleep(sleep_time)
# Out:
# 11
# 20
# 31
# 40
# 53
# 70
# 88
# 99
# 107
# 117
# 134
# 144
# 152
# 163
# 174
# 179
# 191
# 200
# 210
# 224
# 236
# 253
# 266
# 279
# 296
# 304
# 316
# 322
# 331
# 345
# 360
# 370
# 376
# 384
# 390
# 409
# 416
# 428
# 438
# 457
# 474
# 485
# 500
# 514
# 531
# 549
# 562
# 582
# 599
# 614
# 627
# 650
# 671
# 695
# 713
# 745
# 774
# 801
# 838
# 876
# 921
# 965
# 1004
# 1045
# 1090
# 1143
# 1196
# 1250
# 1310
# 1353
# 1400
# 1451
# 1505
# 1554
# 1608
# 1649
# 1690
# 1742
# 1796
# 1857
# 1913
# 1959
# 2016
# 2073
# 2120
# 2165
# 2211
# 2257
# 2301
# 2340
# 2379
# 2412
# 2452
# 2491
# 2525
# 2564
# 2599
# 2634
# 2671
# 2705
# 2742
# 2779
# 2821
# 2849
# 2878
# 2910
# 2933
# 2950
# 2969
# 2987
# 3003
# 3018
# 3035
# 3055
# 3070
# 3084
# 3109
# 3128
# 3150
# 3175
# 3195
# 3206
# 3216
# 3228
# 3246
# 3257
# 3274
# 3295
# 3303
# 3314
# 3328
# 3341
# 3356
# 3365
# 3372
# 3386
# 3392
# 3404
# 3417
# 3427
# 3441
# 3451
# 3458
# 3466
# 3478
# 3494
# 3511
# 3526
# 3538
# 3555
# 3564
# 3578
# ...

# %%
tweets_df 
tweets.to_csv("7 days mba tweets.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-114-3b603059b083> in <module>
# ----> 1 tweets.to_csv("7 days mba tweets.csv",index=False)
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %%
import csv

keys = tweets[0].keys()
with open('7 days mba tweets.csv', 'w', newline='',encoding="utf-8")  as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(tweets)

# %% [markdown]
# # Selenium Scraping

# %%
import pandas as pd 
from selenium import webdriver

# %%
words = ["covid","corona","virus","pandemic","admission","immigrant","immigrate","admit","job","risk","risky",
          "economy","economic","economical","roi","defer","deferment","deferral","deferred","visa","opt",
         "canada","domestic","foreign","extend","extended","extending","gap","abroad","delay","delaying",
         "US","USA","Canada","Australia","STEM","opt","cpt","business_school","international_students"]
word = '%20OR%20'.join(words)
words[0] = '%23'+words[0]
hashed_words = '%20OR%20%23'.join(words)
path1 = "https://twitter.com/search?q=covid%20\"business%20school\"%20("+word+")%20lang%3Aen%20since%3A2020-01-01&src=typed_query"
#path2 = "https://twitter.com/search?q=covid%20\"business%20school\"%20("+hashed_words+")%20lang%3Aen%20since%3A2020-01-01&src=typed_query"
#

# %%
browser = webdriver.Chrome(executable_path='chromedriver.exe')
browser.get("https://twitter.com/search?q=covid%20%22business%20school%22&src=typed_query")

# %%
#Timeline: Search timeline
data = browser.find_elements_by_xpath("//div[@aria-label='Timeline: Search timeline']")

# %%
for d in data:
    print(d.text)
# Out:
# Know the facts
# To make sure you get the best information on the coronavirus (COVID-19), resources are available from the Centers for Disease Control and Prevention (CDC).
# Centers for Disease Control and Prevention
# @CDCGov
# COVID-19
# COVID-19: Updates for the US
# People
# World Health Organization (WHO)
# @WHO
# Follow
# We are the #UnitedNations’ health agency. We are committed to achieving better health for everyone, everywhere - #HealthForAll
# CDC
# @CDCgov
# Follow
# CDC's official Twitter source for daily credible health & safety updates from Centers for Disease Control & Prevention. Privacy policy: http://bit.ly/2MhQ6Hp
# Trevor Bedford
# @trvrb
# Follow
# Scientist
# @fredhutch
# , studying viruses, evolution and immunity. Collection of #COVID19 threads here: https://bedford.io/misc/twitter/
# View all
# EFMD News
# @EFMDNews
# ·
# Aug 5
# ...

# %%
from selenium import webdriver
from getpass import getpass

username = "sakshijoshi320@gmail.com"#input("user name : ")
password = "Sakshi0596@"#getpass("password  : ")
driver = webdriver.Chrome(executable_path='chromedriver.exe')
driver.get("https://twitter.com/login")

username_field = driver.find_element_by_name("session[username_or_email]")
password_field = driver.find_element_by_name("session[password]")

username_field.send_keys(username)
driver.implicitly_wait(1)

password_field.send_keys(password)
driver.implicitly_wait(1)

driver.find_element_by_xpath("//div[@data-testid='LoginForm_Login_Button']").click()

# %% [markdown]
# # Twitter Scrapping using selenium

# %%
 search_words = ["Harvard Business"]
# "stanford business",
# "columbia business school",
# "ucla anderson school of management",
# "nyu stern",
# "wharton school",
# "berkeleyHaas",
# "chicago booth",
# "kellogg school",
# "mitsloan",
# "tuck business school",
# "cornell business school",
# "ross school of business",
# "yale school of management",
# "dardenMBA",
# "duke fuqua",
# "tepper school",
# "texas mccombs",
# "USC Marshall"]
# "rice business",
# "msu broad college of business",
# "georgia tech scheller college of business",
# "owen graduate school of management",
# "Uwfosterschool"]

words = []
for word in search_words:
    word = re.sub(" ","%20",word)
    #words.append(word)
    path = "https://twitter.com/search?q=%22"+word+"%22%20lang%3Aen%20since%3A2020-01-01&src=typed_query&f=live"
    print(path)
# Out:
# https://twitter.com/search?q=%22Harvard%20Business%22%20lang%3Aen%20since%3A2020-01-01&src=typed_query&f=live

# %%
import pandas as pd
from selenium import webdriver
import time
SCROLL_PAUSE_TIME = 2
tweets = []

for word in search_words:
    word = re.sub(" ","%20",word)
    #words.append(word)
    driver = webdriver.Chrome(executable_path='chromedriver.exe')
    path = "https://twitter.com/search?q=%22"+word+"%22%20lang%3Aen%20since%3A2020-01-01&src=typed_query&f=live"
    driver.get(path)
    time.sleep(10)
    #tweets=[]
    data = driver.find_elements_by_xpath("//div[@aria-label='Timeline: Search timeline']")
    last_height = driver.execute_script("return document.body.scrollHeight")
    
    while True:
        time.sleep(2)
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(SCROLL_PAUSE_TIME)

        data = driver.find_elements_by_xpath("//div[@aria-label='Timeline: Search timeline']")

        for d in data:
            tweets.append(d.text)
            #print(d.text)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
        
    tweets_lst = []
    for tweet in tweets:
        tweets_lst.append(re.split("(\@[A-z0-9_]+\\n·)",tweet))
        
    tweets_lst = [j for i in tweets_lst for j in i]
    
    author=[]
    tweets=[]
    date = []
    for tweet in tweets_lst:
        if tweet.startswith("@"):
            a = tweet.split("@")[1]
            author.append(a.split("\n")[0])
            #tweets['Author'].append(tweet)
            #continue
        elif tweet.startswith("\n"):
            #print(tweet)
            d = tweet.split("\n",1)[1]
            date.append(d.split("\n",1)[0])
            tweet = d.split("\n",1)[1]

            tweets.append(re.sub("\n","",tweet))
            #break
        else:
            continue
     
    tweets_df = pd.DataFrame(date,columns=["Date"])
    uth = pd.DataFrame(author,columns=["Author"])
    tweet = pd.DataFrame(tweets,columns=["Tweet"])
    tweets_df = tweets_df.join(uth)
    tweets_df = tweets_df.join(tweet)
    #tweets_df = pd.DataFrame(tweets)
    #tweets_df = tweets_df.transpose
    print(tweets_df)
    #tweets_df.columns=['Date','Author','Tweet']
    #print(tweets_df)
    
    tweets_df.to_csv("2020 "+word+" tweets.csv",index=False)
# Out:
#         Date           Author  \
# 0         2h   AldenEducation
# 1         2h      KapTestNews
# 2         2h    4CornersGroup
# 3         2h  michael_olenick
# 4         3h      StatWizards
# ...      ...              ...
# 2832  Jun 27        luzlights
# 2833  Jun 27     Dr_Rampersad
# 2834  Jun 27     Dr_Rampersad
# 2835  Jun 27     Dr_Rampersad
# 2836  Jun 27     Dr_Rampersad
#
#                                                   Tweet
# 0     RT KapTestNews: Harvard Business School is now...
# 1     Harvard Business School is now offering a test...
# 2     Has this year been the biggest test of your le...
# 3     With defaults in residential and commercial re...
# 4     What is the solution to a very common problem?...
# ...                                                 ...
# 2832  wait can someone link me that Harvard Business...
# 2833  Why is Harvard Business School so White?https:...
# 2834  Why is Harvard Business School so White?https:...
# ...

# %%
import time
import re
SCROLL_PAUSE_TIME = 2
tweets = []
# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    data = driver.find_elements_by_xpath("//div[@aria-label='Timeline: Search timeline']")
    
    for d in data:
        tweets.append(d.text)
        print(d.text)
        
    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height
# Out:
# Teacakers
# @teacakers
# ·
# Dec 30, 2019
# I’ve been saying this! This entire Year of Return better be a case study in business school.
# Quote Tweet
# Everette
# @Everette
#  · Dec 29, 2019
# Ghana’s Tourism Board deserves a marketing award
# 1
# wearAmask
# @azstsndvl
# ·
# Dec 30, 2019
# Replying to
# @DillonCaraballo
# Again, why are you responding to a person that doesn't have a personal photo as their profile pic?
#
# Do some more research before you talk shit about ASU.  Top 10  business school in the WORLD.  Top 20 in Engineering, Nursing and Top 30 for the Sandra Day O'Connor Law School.
# Ujiro Ofidhe
# @Ujiro_Ofidhe
# ·
# Dec 30, 2019
# Replying to
# @umar_ayotunde
#  and
# @officialnairam1
# UNILAG proposed business school building. Recognize that shit anywhere in this life
# AJ, the One
# @ajthe1ne
# ·
# Dec 30, 2019
# Just found out I got a full ride to this Business School for Creatives program that teaches artists how to turn talent into income. I need this so bad
# ...

# %%
import re
tweets_lst = []
for tweet in tweets:
    tweets_lst.append(re.split("(\@[A-z0-9_]+\\n·)",tweet))
    #print("\n")

# %%
len(tweets_lst)
# Out:
# 6

# %%
tweets_lst
# Out:
# [['Ithaca College Alumni\n',
#   '@icalumni\n·',
#   '\nDec 20, 2019\nThe \n@IC_Business\n School was once again named a Top Undergraduate Business School by “Poets & Quants for Undergrads,” a news outlet that covers business education.\nIthaca College’s School of Business Again Named a Top Program | Ithaca College\n“Poets & Quants for Undergrads” releases its list of the best undergraduate business schools for 2020.\nithaca.edu\n15\n33\nANDREA MORRISON\n',
#   '@morrisonXandrea\n·',
#   '\nDec 24, 2019\nStill a few days to submit! 3rd Workshop "#Migration and #Innovation" (deadline January 7), at \n@Unibocconi\n May 18-19, 2020. Keynote speakers: Megan MacGarvie (Boston University) and \n@prithwic\n  (Harvard Business School). More information:\nhttps://tkc-anr.eu/index.php/call-for-papers/…\n10\n8\nCUBS\n',
#   '@CUBSucc\n·',
#   '\nDec 24, 2019\nHappy Christmas from all at Cork University Business School #HappyChristmas\n1\n2\n9\nIrek Tuniewicz\n',
#   '@RoninPoland\n·',
# ...

# %%
tweets_lst = [j for i in tweets_lst for j in i]

# %%
tweets_df.transpose
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-248b1bb6713a> in <module>
# ----> 1 tweets_df.transpose
#
# AttributeError: 'function' object has no attribute 'transpose'

# %%
import pandas as pd
author=[]
tweets=[]
date = []
for tweet in tweets_lst:
    if tweet.startswith("@"):
        a = tweet.split("@")[1]
        author.append(a.split("\n")[0])
        #tweets['Author'].append(tweet)
        #continue
    elif tweet.startswith("\n"):
        #print(tweet)
        d = tweet.split("\n",1)[1]
        date.append(d.split("\n",1)[0])
        tweet = d.split("\n",1)[1]
        
        tweets.append(re.sub("\n","",tweet))
        #break
    else:
        continue
        #tweets_lst.remove(tweet)
    #break

# %%
#date = date.append(author)
tweets = [date,author,tweets]
tweets_df = pd.DataFrame(tweets)
tweets_df = tweets_df.transpose()

# %%
tweets_df.columns=['Date','Author','Tweet']
tweets_df
# Out:
#               Date        Author  \
# 0     Dec 30, 2019     teacakers
# 1     Dec 30, 2019     azstsndvl
# 2     Dec 30, 2019  Ujiro_Ofidhe
# 3     Dec 30, 2019      ajthe1ne
# 4     Dec 30, 2019        24uNet
# ...            ...           ...
# 5834   Dec 4, 2019   GEMSBSchool
# 5835   Dec 4, 2019        ftlive
# 5836   Dec 4, 2019   holdahamaka
# 5837   Dec 4, 2019           LBS
# 5838   Dec 4, 2019   GEMSBSchool
#
#                                                   Tweet
# 0     I’ve been saying this! This entire Year of Ret...
# 1     Replying to @DillonCaraballoAgain, why are you...
# 2     Replying to @umar_ayotunde and @officialnairam...
# 3     Just found out I got a full ride to this Busin...
# 4     A new study from Harvard Business School calcu...
# ...                                                 ...
# 5834  ‘You Only B-School Once’ a book by Kunj Sanghv...
# 5835  Is sustainable finance a realistic objective o...
# ...

# %%
tweets_df.to_csv("2 year business school tweets.csv",index=False)
